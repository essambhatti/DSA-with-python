# %% [markdown]
# ## Bubble Sort Code

# %%
def bubble_sort(arr):
    for i in range(len(arr)):
        for j in range(len(arr)-i-1):
            if arr[j] > arr [j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
    return arr


print(bubble_sort([2, 3, 6, 12, 7, 9, 10]))
# Out:
# [2, 3, 6, 7, 9, 10, 12]
