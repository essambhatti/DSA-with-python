# %% [markdown]
# #### Stack is a Data Structure (LIFO - Last In First Out)

# %% [markdown]
# ##### Application : Undo / Redo

# %% [markdown]
# A stack made from linked list is just a linked list with all operation from head only
